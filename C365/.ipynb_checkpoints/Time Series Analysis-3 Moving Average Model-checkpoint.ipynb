# %% [markdown]
# ## Moving Average Model
#
# 1. Maths behind the model
# 2. Coding
# 3. Selecting the Model
# 4. Coefficients and LLF
# 5. Residual analysis
# 6. Logs analysis
# 7. Price predictions
#
# The MA model includes past residuals while the AR model includes past values.

# %% [markdown]
# ### Simple Moving Average

# %%
from IPython.display import Image
Image(filename='SimpleMAF.jpg')

# %%
Image(filename='ARvsMA.jpg')

# %% [markdown]
# ### Please read the AR and MA pdf files associated with Moving averages

# %%
import numpy as np
import pandas as pd
import yfinance 

# Ignoring warning messages
import warnings 
warnings.filterwarnings("ignore")

# %%
# Getting the current date
from datetime import date
today = date.today()
today
# Out:
# datetime.date(2020, 7, 18)

# %%
# Using the .download() method to get our data

raw_data = yfinance.download (tickers = "^GSPC ^FTSE ^N225 ^GDAXI", #The time series we are interested in - (in our case, these are the S&P, FTSE, NIKKEI and DAX)
                              start = "1994-01-07", #The starting date of our data set
                              end = today, #The ending date of our data set (at the time of upload, this is the current date)
                              interval = "1d", #The distance in time between two recorded observations. Since we're using daily closing prices, we set it equal to "1d", which indicates 1 day. 
                              group_by = 'ticker', #The way we want to group the scraped data. Usually we want it to be "ticker", so that we have all the information about a time series in 1 variable.
                              auto_adjust = True, #Automatically adjuss the closing prices for each period. 
                              treads = True) #Whether to use threads for mass downloading.
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
# Creating a back up copy in case we remove/alter elements of the data by mistake
df_comp = raw_data.copy()

# %%
# Adding new columns to the data set
df_comp['spx'] = df_comp['^GSPC'].Close
df_comp['dax'] = df_comp['^GDAXI'].Close
df_comp['ftse'] = df_comp['^FTSE'].Close
df_comp['nikkei'] = df_comp['^N225'].Close

# %%
df_comp = df_comp.iloc[1:] # Removing the first elements, since we always start 1 period before the first, due to time zone differences of closing prices
del df_comp['^N225']  # Removing the original tickers of the data set
del df_comp['^GSPC']
del df_comp['^GDAXI']
del df_comp['^FTSE']
df_comp=df_comp.asfreq('b') # Setting the frequency of the data
df_comp=df_comp.fillna(method='ffill') # Filling any missing values

# %%
print (df_comp.head()) # Displaying the first 5 elements to make sure the data was scrapped correctly
print (df_comp.tail()) # Making sure of the last day we're including in the series
# Out:
#                    spx          dax         ftse        nikkei
#
# Date
# 1994-01-07  469.899994  2224.949951  3446.000000  18124.009766
# 1994-01-10  475.269989  2225.000000  3440.600098  18443.439453
# 1994-01-11  474.130005  2228.100098  3413.800049  18485.250000
# 1994-01-12  474.170013  2182.060059  3372.000000  18793.880859
# 1994-01-13  472.470001  2142.370117  3360.000000  18577.259766
#                     spx           dax         ftse        nikkei
#
# Date
# 2020-07-13  3155.219971  12799.969727  6176.200195  22784.740234
# 2020-07-14  3197.520020  12697.360352  6179.799805  22587.009766
# 2020-07-15  3226.560059  12930.980469  6292.700195  22945.500000
# 2020-07-16  3215.570068  12874.969727  6250.700195  22770.359375
# 2020-07-17  3229.800049  12919.610352  6290.299805  22696.419922

# %%
# while dealing with huge database and you want to analyse only one column
df_comp.spx.isna().sum()
# Out:
# 0

# %%
df_comp['market_value'] = df_comp.ftse

# %%
col = ["spx", "dax", "ftse", "nikkei"]

for x in col:
    del df_comp[x]

# %%
train_size = int(len(df_comp)*0.8)

# %%
df = df_comp.iloc[: train_size]

# %%
df_test = df_comp.iloc[train_size :]

# %%
import statsmodels.tsa.stattools as sts
import statsmodels.graphics.tsaplots as sgt
import matplotlib.pyplot as plt
import statsmodels.tsa.arima_model as sta

# %%
# LLR Test method
import scipy.stats.distributions as dis

# Here mod_1 and mod_2 are models we have to compare and DF is the degrees of freedom.
def LLR_test(mod_1, mod_2, DF = 1):
    L1 = mod_1.fit().llf
    L2 = mod_2.fit().llf
    LR = (2*(L2-L1))
    p = dis.chi2.sf(LR, DF).round(3)
    return p

# %%
df['returns'] = df.market_value.pct_change(1).mul(100)
df = df.iloc[1:]

# %% [markdown]
# ## ACF Plot

# %%
sgt.plot_acf(df.returns, lags = 40, zero = False)
plt.title("ACF FTSE-Returns", size = 24)
plt.show()

# %% [markdown]
# ### MA(1) for returns

# %%
model_ret_ma_1 = sta.ARMA(df.returns[1:], order = (0, 1))
result_ret_ma_1 = model_ret_ma_1.fit()
result_ret_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 1)   Log Likelihood               -8586.505
# Method:                       css-mle   S.D. of innovations              1.142
# Date:                Sat, 18 Jul 2020   AIC                          17179.010
# Time:                        00:56:40   BIC                          17198.866
# Sample:                    01-11-1994   HQIC                         17185.933
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0190      0.015      1.268      0.205      -0.010       0.048
# ma.L1.returns    -0.0245      0.014     -1.721      0.085      -0.052       0.003
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           40.8819           +0.0000j           40.8819            0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# ## Higher Lag MA models

# %%
model_ret_ma_2 = sta.ARMA(df.returns[1:], order = (0, 2))
result_ret_ma_2 = model_ret_ma_2.fit()
print(result_ret_ma_2.summary())
print("\nLLR test p-value = "+ str(LLR_test(model_ret_ma_1, model_ret_ma_2)))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 2)   Log Likelihood               -8579.583
# Method:                       css-mle   S.D. of innovations              1.140
# Date:                Sat, 18 Jul 2020   AIC                          17167.165
# Time:                        00:56:40   BIC                          17193.640
# Sample:                    01-11-1994   HQIC                         17176.397
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0190      0.014      1.348      0.178      -0.009       0.047
# ma.L1.returns    -0.0306      0.014     -2.263      0.024      -0.057      -0.004
# ma.L2.returns    -0.0486      0.013     -3.721      0.000      -0.074      -0.023
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            4.2327           +0.0000j            4.2327            0.0000
# MA.2           -4.8624           +0.0000j            4.8624            0.5000
# -----------------------------------------------------------------------------
#
# LLR test p-value = 0.0

# %%
model_ret_ma_3 = sta.ARMA(df.returns[1:], order = (0, 3))
result_ret_ma_3 = model_ret_ma_3.fit()
print(result_ret_ma_3.summary())
print("\nLLR test p-value = "+ str(LLR_test(model_ret_ma_2, model_ret_ma_3)))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 3)   Log Likelihood               -8562.362
# Method:                       css-mle   S.D. of innovations              1.137
# Date:                Sat, 18 Jul 2020   AIC                          17134.725
# Time:                        00:56:41   BIC                          17167.818
# Sample:                    01-11-1994   HQIC                         17146.264
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.013      1.480      0.139      -0.006       0.044
# ma.L1.returns    -0.0200      0.014     -1.478      0.139      -0.047       0.007
# ma.L2.returns    -0.0535      0.013     -4.154      0.000      -0.079      -0.028
# ma.L3.returns    -0.0825      0.014     -5.894      0.000      -0.110      -0.055
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            2.0680           -0.0000j            2.0680           -0.0000
# MA.2           -1.3579           -2.0037j            2.4205           -0.3448
# MA.3           -1.3579           +2.0037j            2.4205            0.3448
# -----------------------------------------------------------------------------
#
# LLR test p-value = 0.0

# %%
model_ret_ma_4 = sta.ARMA(df.returns[1:], order = (0, 4))
result_ret_ma_4 = model_ret_ma_4.fit()
print(result_ret_ma_4.summary())
print("\nLLR test p-value = "+ str(LLR_test(model_ret_ma_3, model_ret_ma_4)))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 4)   Log Likelihood               -8557.228
# Method:                       css-mle   S.D. of innovations              1.136
# Date:                Sat, 18 Jul 2020   AIC                          17126.457
# Time:                        00:56:42   BIC                          17166.169
# Sample:                    01-11-1994   HQIC                         17140.304
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.014      1.412      0.158      -0.007       0.046
# ma.L1.returns    -0.0198      0.013     -1.473      0.141      -0.046       0.007
# ma.L2.returns    -0.0531      0.013     -3.955      0.000      -0.079      -0.027
# ma.L3.returns    -0.0844      0.014     -6.076      0.000      -0.112      -0.057
# ma.L4.returns     0.0419      0.013      3.211      0.001       0.016       0.067
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.2599           -1.4518j            1.9223           -0.3638
# MA.2           -1.2599           +1.4518j            1.9223            0.3638
# MA.3            2.2675           -1.1496j            2.5423           -0.0747
# MA.4            2.2675           +1.1496j            2.5423            0.0747
# -----------------------------------------------------------------------------
#
# LLR test p-value = 0.001

# %%
model_ret_ma_5 = sta.ARMA(df.returns[1:], order = (0, 5))
result_ret_ma_5 = model_ret_ma_5.fit()
print(result_ret_ma_5.summary())
print("\nLLR test p-value = "+ str(LLR_test(model_ret_ma_4, model_ret_ma_5)))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 5)   Log Likelihood               -8550.960
# Method:                       css-mle   S.D. of innovations              1.135
# Date:                Sat, 18 Jul 2020   AIC                          17115.919
# Time:                        00:56:44   BIC                          17162.250
# Sample:                    01-11-1994   HQIC                         17132.074
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.013      1.486      0.137      -0.006       0.044
# ma.L1.returns    -0.0250      0.013     -1.857      0.063      -0.051       0.001
# ma.L2.returns    -0.0481      0.013     -3.577      0.000      -0.075      -0.022
# ma.L3.returns    -0.0783      0.014     -5.621      0.000      -0.106      -0.051
# ma.L4.returns     0.0424      0.013      3.260      0.001       0.017       0.068
# ma.L5.returns    -0.0488      0.014     -3.544      0.000      -0.076      -0.022
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.2330           -1.0856j            1.6428           -0.3851
# MA.2           -1.2330           +1.0856j            1.6428            0.3851
# MA.3            1.7441           -0.0000j            1.7441           -0.0000
# MA.4            0.7958           -1.9294j            2.0871           -0.1877
# MA.5            0.7958           +1.9294j            2.0871            0.1877
# -----------------------------------------------------------------------------
#
# LLR test p-value = 0.0

# %%
model_ret_ma_6 = sta.ARMA(df.returns[1:], order = (0, 6))
result_ret_ma_6 = model_ret_ma_6.fit()
print(result_ret_ma_6.summary())
print("\nLLR test p-value = "+ str(LLR_test(model_ret_ma_5, model_ret_ma_6)))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 6)   Log Likelihood               -8547.642
# Method:                       css-mle   S.D. of innovations              1.134
# Date:                Sat, 18 Jul 2020   AIC                          17111.285
# Time:                        00:56:48   BIC                          17164.234
# Sample:                    01-11-1994   HQIC                         17129.748
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.012      1.538      0.124      -0.005       0.043
# ma.L1.returns    -0.0227      0.013     -1.688      0.091      -0.049       0.004
# ma.L2.returns    -0.0474      0.013     -3.521      0.000      -0.074      -0.021
# ma.L3.returns    -0.0761      0.013     -5.649      0.000      -0.102      -0.050
# ma.L4.returns     0.0430      0.013      3.305      0.001       0.018       0.069
# ma.L5.returns    -0.0476      0.014     -3.476      0.001      -0.074      -0.021
# ma.L6.returns    -0.0354      0.014     -2.574      0.010      -0.062      -0.008
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.5186           -0.0000j            1.5186           -0.0000
# MA.2            0.8248           -1.4956j            1.7079           -0.1698
# MA.3            0.8248           +1.4956j            1.7079            0.1698
# MA.4           -1.0322           -1.2406j            1.6139           -0.3604
# MA.5           -1.0322           +1.2406j            1.6139            0.3604
# MA.6           -2.4462           -0.0000j            2.4462           -0.5000
# -----------------------------------------------------------------------------
#
# LLR test p-value = 0.01

# %%
model_ret_ma_7 = sta.ARMA(df.returns[1:], order = (0, 7))
result_ret_ma_7 = model_ret_ma_7.fit()
print(result_ret_ma_7.summary())
print("\nLLR test p-value = "+ str(LLR_test(model_ret_ma_6, model_ret_ma_7)))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 7)   Log Likelihood               -8547.373
# Method:                       css-mle   S.D. of innovations              1.134
# Date:                Sat, 18 Jul 2020   AIC                          17112.747
# Time:                        00:56:53   BIC                          17172.315
# Sample:                    01-11-1994   HQIC                         17133.517
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.013      1.523      0.128      -0.005       0.044
# ma.L1.returns    -0.0236      0.013     -1.754      0.080      -0.050       0.003
# ma.L2.returns    -0.0477      0.013     -3.546      0.000      -0.074      -0.021
# ma.L3.returns    -0.0754      0.013     -5.586      0.000      -0.102      -0.049
# ma.L4.returns     0.0422      0.013      3.229      0.001       0.017       0.068
# ma.L5.returns    -0.0476      0.014     -3.484      0.000      -0.074      -0.021
# ma.L6.returns    -0.0357      0.014     -2.594      0.009      -0.063      -0.009
# ma.L7.returns     0.0100      0.014      0.733      0.463      -0.017       0.037
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -0.9816           -1.1852j            1.5389           -0.3601
# MA.2           -0.9816           +1.1852j            1.5389            0.3601
# MA.3           -2.0166           -0.0000j            2.0166           -0.5000
# MA.4            0.7273           -1.5467j            1.7092           -0.1800
# MA.5            0.7273           +1.5467j            1.7092            0.1800
# MA.6            1.5918           -0.0000j            1.5918           -0.0000
# MA.7            4.4969           -0.0000j            4.4969           -0.0000
# -----------------------------------------------------------------------------
#
# LLR test p-value = 0.463

# %%
model_ret_ma_8 = sta.ARMA(df.returns[1:], order = (0, 8))
result_ret_ma_8 = model_ret_ma_8.fit()
print(result_ret_ma_8.summary())
print("\nLLR test p-value = "+ str(LLR_test(model_ret_ma_7, model_ret_ma_8)))
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 8)   Log Likelihood               -8544.694
# Method:                       css-mle   S.D. of innovations              1.133
# Date:                Sat, 18 Jul 2020   AIC                          17109.388
# Time:                        00:57:02   BIC                          17175.575
# Sample:                    01-11-1994   HQIC                         17132.467
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.013      1.474      0.140      -0.006       0.044
# ma.L1.returns    -0.0230      0.013     -1.715      0.086      -0.049       0.003
# ma.L2.returns    -0.0482      0.013     -3.586      0.000      -0.074      -0.022
# ma.L3.returns    -0.0774      0.013     -5.750      0.000      -0.104      -0.051
# ma.L4.returns     0.0447      0.014      3.305      0.001       0.018       0.071
# ma.L5.returns    -0.0501      0.014     -3.682      0.000      -0.077      -0.023
# ma.L6.returns    -0.0365      0.014     -2.652      0.008      -0.063      -0.010
# ma.L7.returns     0.0102      0.014      0.749      0.454      -0.016       0.037
# ma.L8.returns     0.0307      0.013      2.316      0.021       0.005       0.057
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.4972           -0.4366j            1.5596           -0.0452
# MA.2            1.4972           +0.4366j            1.5596            0.0452
# MA.3            0.5967           -1.3407j            1.4675           -0.1834
# MA.4            0.5967           +1.3407j            1.4675            0.1834
# MA.5           -0.7625           -1.2942j            1.5021           -0.3347
# MA.6           -0.7625           +1.2942j            1.5021            0.3347
# MA.7           -1.4974           -0.7172j            1.6603           -0.4289
# MA.8           -1.4974           +0.7172j            1.6603            0.4289
# -----------------------------------------------------------------------------
#
# LLR test p-value = 0.021

# %%
LLR_test(model_ret_ma_6, model_ret_ma_8, DF=2)
# Out:
# 0.052

# %% [markdown]
# We can see clearly that the value is higher than 0.05 so model 6 is better to go with than 8.

# %%
LLR_test(model_ret_ma_5, model_ret_ma_8, DF=3)
# Out:
# 0.006

# %% [markdown]
# We can see clearly that the value is lower than 0.05 so model 8 is better to go with than 5.
#
# We select model 6 as the final model.
#
# ## Residual of Returns

# %%
df['res_ret_ma_6'] = result_ret_ma_6.resid[1:]

# %%
print("The mean of residual is: " + str(round(df.res_ret_ma_6.mean(), 3)))
print("The variance of residual is: " + str(round(df.res_ret_ma_6.var(), 3)))
# Out:
# The mean of residual is: 0.0
# The variance of residual is: 1.286

# %%
import math
round(math.sqrt(df.res_ret_ma_6.var()), 3)
# Out:
# 1.134

# %%
df.res_ret_ma_6[1:].plot(figsize = (20,5))
plt.title("Residuals of Returns", size = 24)
plt.show()

# %%
sts.adfuller(df.res_ret_ma_6[2:])
# Out:
# (-13.908110809882114,
#  5.574529671119883e-26,
#  33,
#  5499,
#  {'1%': -3.431539735439507,
#   '5%': -2.862065744914038,
#   '10%': -2.567049852849636},
#  16995.137748059187)

# %%
sgt.plot_acf(df.res_ret_ma_6[2:], zero = False, lags = 40)
plt.title("ACF of Residuals for Returns", size = 24)
plt.show()

# %% [markdown]
# ## Normalized Returns

# %%
bench_ret = df.returns.iloc[1]
df['norm_ret'] = df.returns.div(bench_ret).mul(100)

# %%
sgt.plot_acf(df.norm_ret[1:], zero = False, lags = 40)
plt.title("ACF of Normalized Returns", size = 24)
plt.show()

# %%
model_norm_ret_ma_6 = sta.ARMA(df.norm_ret[1:], order = (0, 6))
result_norm_ret_ma_6 = model_norm_ret_ma_6.fit()
print(result_norm_ret_ma_6.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               norm_ret   No. Observations:                 5534
# Model:                     ARMA(0, 6)   Log Likelihood              -35415.198
# Method:                       css-mle   S.D. of innovations            145.565
# Date:                Sat, 18 Jul 2020   AIC                          70846.397
# Time:                        00:59:41   BIC                          70899.346
# Sample:                    01-11-1994   HQIC                         70864.860
#                          - 03-27-2015
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -2.4506      1.593     -1.539      0.124      -5.572       0.671
# ma.L1.norm_ret    -0.0227      0.013     -1.688      0.091      -0.049       0.004
# ma.L2.norm_ret    -0.0474      0.013     -3.521      0.000      -0.074      -0.021
# ma.L3.norm_ret    -0.0761      0.013     -5.649      0.000      -0.102      -0.050
# ma.L4.norm_ret     0.0430      0.013      3.305      0.001       0.018       0.069
# ma.L5.norm_ret    -0.0476      0.014     -3.476      0.001      -0.074      -0.021
# ma.L6.norm_ret    -0.0354      0.014     -2.574      0.010      -0.062      -0.008
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.5186           -0.0000j            1.5186           -0.0000
# MA.2            0.8248           -1.4956j            1.7079           -0.1698
# MA.3            0.8248           +1.4956j            1.7079            0.1698
# MA.4           -1.0322           -1.2406j            1.6139           -0.3604
# MA.5           -1.0322           +1.2406j            1.6139            0.3604
# MA.6           -2.4462           -0.0000j            2.4462           -0.5000
# -----------------------------------------------------------------------------

# %%
print(result_ret_ma_6.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(0, 6)   Log Likelihood               -8547.642
# Method:                       css-mle   S.D. of innovations              1.134
# Date:                Sat, 18 Jul 2020   AIC                          17111.285
# Time:                        01:00:07   BIC                          17164.234
# Sample:                    01-11-1994   HQIC                         17129.748
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.012      1.538      0.124      -0.005       0.043
# ma.L1.returns    -0.0227      0.013     -1.688      0.091      -0.049       0.004
# ma.L2.returns    -0.0474      0.013     -3.521      0.000      -0.074      -0.021
# ma.L3.returns    -0.0761      0.013     -5.649      0.000      -0.102      -0.050
# ma.L4.returns     0.0430      0.013      3.305      0.001       0.018       0.069
# ma.L5.returns    -0.0476      0.014     -3.476      0.001      -0.074      -0.021
# ma.L6.returns    -0.0354      0.014     -2.574      0.010      -0.062      -0.008
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1            1.5186           -0.0000j            1.5186           -0.0000
# MA.2            0.8248           -1.4956j            1.7079           -0.1698
# MA.3            0.8248           +1.4956j            1.7079            0.1698
# MA.4           -1.0322           -1.2406j            1.6139           -0.3604
# MA.5           -1.0322           +1.2406j            1.6139            0.3604
# MA.6           -2.4462           -0.0000j            2.4462           -0.5000
# -----------------------------------------------------------------------------

# %%
df['res_norm_ret_ma_6'] = result_norm_ret_ma_6.resid[1:]

# %%
df.res_norm_ret_ma_6[1:].plot(figsize = (20,5))
plt.title("Residuals of Returns", size = 24)
plt.show()

# %%
sgt.plot_acf(df.res_norm_ret_ma_6[2:], zero = False, lags = 40)
plt.title("ACF of Residuals for Returns", size = 24)
plt.show()

# %% [markdown]
# ## MA Model for Prices

# %%
sgt.plot_acf(df.market_value, zero = False, lags = 40)
plt.title("ACF of Prices", size = 24)
plt.show()

# %% [markdown]
# According to the above graph with the increment of lags the model accuracy will increase but that is not correct so lets try some more models on this data.
#
# ARMA: AutoRegressive Moving Average Model
# (P1, P2): P1 = Lagged Values, P2 = Lagged Errors

# %%
model_ma_1 = sta.ARMA(df.market_value, order = (0, 1))
result_model_ma_1 = model_ma_1.fit()
print(result_model_ma_1.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:           market_value   No. Observations:                 5535
# Model:                     ARMA(0, 1)   Log Likelihood              -42841.682
# Method:                       css-mle   S.D. of innovations            556.113
# Date:                Sat, 18 Jul 2020   AIC                          85689.363
# Time:                        19:57:15   BIC                          85709.220
# Sample:                    01-10-1994   HQIC                         85696.287
#                          - 03-27-2015
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const               5234.0347     14.655    357.143      0.000    5205.311    5262.759
# ma.L1.market_value     0.9608      0.003    367.936      0.000       0.956       0.966
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.0408           +0.0000j            1.0408            0.5000
# -----------------------------------------------------------------------------

# %% [markdown]
# ### ARMA Equation
#
# We have 2 types of ARMA model:
#
# 1. ARMA is represented with 2 components (AR,MA)
#
#     AR is the AutoRegressive components
#
#     MA is the MovingAverage components
#
#
#
# 2. ARMA is represented with 2 components (P, Q)
#
#     P takes the previous values upto P periods
#
#     Q takes the residual values upto Q lags

# %%
Image(filename='ARMAeqn.jpg')

# %% [markdown]
# ## ARMA (1,1)
#
# Here we will try to fit a time-series in a simple auto-regressive moving average model. Order will be of type (one previous value, one past error term). The function would be of type:
#
# ARMA(time_series_name, order = (previous value, past error term))

# %%
model_ret_ar_1_ma_1 = sta.ARMA(df.returns[1:], order = (1, 1))
result_ret_ar_1_ma_1 = model_ret_ar_1_ma_1.fit()
result_ret_ar_1_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(1, 1)   Log Likelihood               -8573.319
# Method:                       css-mle   S.D. of innovations              1.139
# Date:                Mon, 20 Jul 2020   AIC                          17154.638
# Time:                        15:44:38   BIC                          17181.113
# Sample:                    01-11-1994   HQIC                         17163.870
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.012      1.574      0.115      -0.005       0.043
# ar.L1.returns     0.7839      0.074     10.661      0.000       0.640       0.928
# ma.L1.returns    -0.8292      0.066    -12.502      0.000      -0.959      -0.699
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.2757           +0.0000j            1.2757            0.0000
# MA.1            1.2060           +0.0000j            1.2060            0.0000
# -----------------------------------------------------------------------------
# """

# %%
model_ret_ar_1 = sts.ARMA(df.returns[1:], order = (1, 0))
model_ret_ma_1 = sts.ARMA(df.returns[1:], order = (0, 1))

# %%
print("\n ARMA Vs. AR: " + str(LLR_test(model_ret_ar_1, model_ret_ar_1_ma_1)))
print("\n ARMA Vs. MA: " + str(LLR_test(model_ret_ma_1, model_ret_ar_1_ma_1)))
# Out:
#  ARMA Vs. AR: 0.0
#
#  ARMA Vs. MA: 0.0

# %% [markdown]
# ### Fitting a higher-lag ARMA model

# %%
Image(filename='OPARMA.jpg')

# %% [markdown]
# The below mentioned features are the features of a best model but it might be overfitting.

# %%
Image(filename='feat_ARMA.jpg')

# %%
model_ret_ar_3_ma_3 = sta.ARMA(df.returns[1:], order = (3, 3))
result_ret_ar_3_ma_3 = model_ret_ar_3_ma_3.fit()

# %%
LLR_test(model_ret_ar_1_ma_1, model_ret_ar_3_ma_3, DF = 4)

# Here DF = 4 because 1st model has 2 coefficients and second model has 6.
# So, 6-2 = 4
# Out:
# 0.0

# %%
result_ret_ar_3_ma_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(3, 3)   Log Likelihood               -8550.811
# Method:                       css-mle   S.D. of innovations              1.135
# Date:                Mon, 20 Jul 2020   AIC                          17117.621
# Time:                        16:08:53   BIC                          17170.571
# Sample:                    01-11-1994   HQIC                         17136.084
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.013      1.521      0.128      -0.006       0.044
# ar.L1.returns    -0.1735      0.088     -1.974      0.048      -0.346      -0.001
# ar.L2.returns    -0.3078      0.074     -4.158      0.000      -0.453      -0.163
# ar.L3.returns     0.5565      0.119      4.674      0.000       0.323       0.790
# ma.L1.returns     0.1527      0.082      1.862      0.063      -0.008       0.313
# ma.L2.returns     0.2470      0.071      3.485      0.000       0.108       0.386
# ma.L3.returns    -0.6392      0.110     -5.822      0.000      -0.854      -0.424
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.4872           -0.9691j            1.0846           -0.3241
# AR.2           -0.4872           +0.9691j            1.0846            0.3241
# AR.3            1.5274           -0.0000j            1.5274           -0.0000
# MA.1           -0.4970           -0.9414j            1.0646           -0.3273
# MA.2           -0.4970           +0.9414j            1.0646            0.3273
# MA.3            1.3805           -0.0000j            1.3805           -0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# According to the p-values there is only one component which is of no use rest are really good.

# %%
model_ret_ar_3_ma_2 = sta.ARMA(df.returns[1:], order = (3, 2))
result_ret_ar_3_ma_2 = model_ret_ar_3_ma_2.fit()
result_ret_ar_3_ma_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(3, 2)   Log Likelihood               -8554.310
# Method:                       css-mle   S.D. of innovations              1.135
# Date:                Mon, 20 Jul 2020   AIC                          17122.620
# Time:                        16:23:26   BIC                          17168.951
# Sample:                    01-11-1994   HQIC                         17138.775
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0190      0.014      1.360      0.174      -0.008       0.046
# ar.L1.returns    -0.6866      0.091     -7.521      0.000      -0.866      -0.508
# ar.L2.returns    -0.4861      0.147     -3.306      0.001      -0.774      -0.198
# ar.L3.returns    -0.1069      0.014     -7.590      0.000      -0.134      -0.079
# ma.L1.returns     0.6657      0.091      7.278      0.000       0.486       0.845
# ma.L2.returns     0.4262      0.149      2.859      0.004       0.134       0.718
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.5370           -1.5507j            1.6410           -0.3031
# AR.2           -0.5370           +1.5507j            1.6410            0.3031
# AR.3           -3.4747           -0.0000j            3.4747           -0.5000
# MA.1           -0.7809           -1.3177j            1.5317           -0.3352
# MA.2           -0.7809           +1.3177j            1.5317            0.3352
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# In a complex model like 3,2 or 2,3 we should avoid doing the LLR test. Because it becomes too complex and the figures that we get are not accurate.

# %%
model_ret_ar_2_ma_3 = sta.ARMA(df.returns[1:], order = (2, 3))
result_ret_ar_2_ma_3 = model_ret_ar_2_ma_3.fit()
result_ret_ar_2_ma_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(2, 3)   Log Likelihood               -8554.070
# Method:                       css-mle   S.D. of innovations              1.135
# Date:                Mon, 20 Jul 2020   AIC                          17122.140
# Time:                        16:24:59   BIC                          17168.470
# Sample:                    01-11-1994   HQIC                         17138.295
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.014      1.388      0.165      -0.008       0.046
# ar.L1.returns    -0.5727      0.095     -6.043      0.000      -0.758      -0.387
# ar.L2.returns    -0.3693      0.274     -1.349      0.177      -0.906       0.167
# ma.L1.returns     0.5508      0.095      5.823      0.000       0.365       0.736
# ma.L2.returns     0.3063      0.275      1.112      0.266      -0.233       0.846
# ma.L3.returns    -0.1094      0.015     -7.130      0.000      -0.139      -0.079
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -0.7753           -1.4514j            1.6455           -0.3281
# AR.2           -0.7753           +1.4514j            1.6455            0.3281
# MA.1           -0.8056           -1.1930j            1.4395           -0.3445
# MA.2           -0.8056           +1.1930j            1.4395            0.3445
# MA.3            4.4107           -0.0000j            4.4107           -0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# According to the p-values there are 2 components which are of no use, so we can go lower in this kind of models.

# %%
LLR_test(model_ret_ar_2_ma_3 ,model_ret_ar_3_ma_3, DF = 1)
# Out:
# 0.011

# %%
# ARMA (3,1)
model_ret_ar_3_ma_1 = sta.ARMA(df.returns[1:], order = (3, 1))
result_ret_ar_3_ma_1 = model_ret_ar_3_ma_1.fit()
result_ret_ar_3_ma_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(3, 1)   Log Likelihood               -8557.387
# Method:                       css-mle   S.D. of innovations              1.136
# Date:                Mon, 20 Jul 2020   AIC                          17126.774
# Time:                        18:54:38   BIC                          17166.486
# Sample:                    01-11-1994   HQIC                         17140.621
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.014      1.406      0.160      -0.008       0.046
# ar.L1.returns    -0.5055      0.090     -5.624      0.000      -0.682      -0.329
# ar.L2.returns    -0.0614      0.015     -4.068      0.000      -0.091      -0.032
# ar.L3.returns    -0.1026      0.013     -7.670      0.000      -0.129      -0.076
# ma.L1.returns     0.4825      0.090      5.372      0.000       0.306       0.659
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.5330           -0.0000j            1.5330           -0.5000
# AR.2            0.4670           -2.4782j            2.5218           -0.2204
# AR.3            0.4670           +2.4782j            2.5218            0.2204
# MA.1           -2.0725           +0.0000j            2.0725            0.5000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# We can clearly see that all the p-values are significant and the AR coefficients are all negative while the MA coefficient is positive. Lets just jump to LLR test this is a good model.

# %%
LLR_test(model_ret_ar_3_ma_1 ,model_ret_ar_3_ma_2, DF = 1)

# Always put the simpler model first else the LLR test will always return 1.
# Out:
# 0.013

# %%
# ARMA(2,2)
model_ret_ar_2_ma_2 = sta.ARMA(df.returns[1:], order = (2, 2))
result_ret_ar_2_ma_2 = model_ret_ar_2_ma_2.fit()
result_ret_ar_2_ma_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(2, 2)   Log Likelihood               -8570.293
# Method:                       css-mle   S.D. of innovations              1.139
# Date:                Mon, 20 Jul 2020   AIC                          17152.587
# Time:                        18:59:12   BIC                          17192.299
# Sample:                    01-11-1994   HQIC                         17166.434
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.013      1.503      0.133      -0.006       0.044
# ar.L1.returns     0.7688      0.236      3.264      0.001       0.307       1.230
# ar.L2.returns    -0.1445      0.178     -0.812      0.417      -0.493       0.204
# ma.L1.returns    -0.7957      0.236     -3.365      0.001      -1.259      -0.332
# ma.L2.returns     0.1073      0.188      0.572      0.567      -0.260       0.475
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            2.2643           +0.0000j            2.2643            0.0000
# AR.2            3.0568           +0.0000j            3.0568            0.0000
# MA.1            1.6036           +0.0000j            1.6036            0.0000
# MA.2            5.8120           +0.0000j            5.8120            0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# We can clearly see that 2 p-values are insignificant. This is not a good model

# %%
#ARMA(1,3)
model_ret_ar_1_ma_3 = sta.ARMA(df.returns[1:], order = (1, 3))
result_ret_ar_1_ma_3 = model_ret_ar_1_ma_3.fit()
result_ret_ar_1_ma_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                returns   No. Observations:                 5534
# Model:                     ARMA(1, 3)   Log Likelihood               -8555.225
# Method:                       css-mle   S.D. of innovations              1.135
# Date:                Mon, 20 Jul 2020   AIC                          17122.450
# Time:                        19:01:32   BIC                          17162.162
# Sample:                    01-11-1994   HQIC                         17136.297
#                          - 03-27-2015
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0191      0.013      1.439      0.150      -0.007       0.045
# ar.L1.returns    -0.4724      0.096     -4.934      0.000      -0.660      -0.285
# ma.L1.returns     0.4508      0.095      4.728      0.000       0.264       0.638
# ma.L2.returns    -0.0616      0.015     -4.169      0.000      -0.091      -0.033
# ma.L3.returns    -0.1101      0.014     -8.002      0.000      -0.137      -0.083
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -2.1166           +0.0000j            2.1166            0.5000
# MA.1           -1.5351           -1.1224j            1.9016           -0.3995
# MA.2           -1.5351           +1.1224j            1.9016            0.3995
# MA.3            2.5111           -0.0000j            2.5111           -0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# This is a good model according the relevant p-values of all the variables. But this also a nested model. The higher lag model is considered as the nested model. For more details check the slide of the model of interest.

# %%
Image(filename='moi.jpg')

# %%
print("\n ARMA(3,2): LL = " + str(result_ret_ar_3_ma_2.llf), "AIC = " + str(result_ret_ar_3_ma_2.aic))
print("\n ARMA(1,3): LL = " + str(result_ret_ar_1_ma_3.llf), "AIC = " + str(result_ret_ar_1_ma_3.aic))
# Out:
#  ARMA(3,2): LL = -8554.310006487318 AIC = 17122.620012974636
#
#  ARMA(1,3): LL = -8555.224815038477 AIC = 17122.449630076953

# %% [markdown]
# Clearly ARMA(3,2) is a better model because of the higher LLR result

# %% [markdown]
# ### Residual of Returns

# %%
df['res_ret_ar_3_ma_2'] = result_ret_ar_3_ma_2.resid[1:]

# %%
df.res_ret_ar_3_ma_2.plot(figsize = (20,5))
plt.title('Residual of Returns', size = 24)
plt.show()

# %% [markdown]
# The above results are very similar to the residuals of AR as well MA models. The volatility in returns might not be fully comprehendable if we use only ARMA model.

# %%
sgt.plot_acf(df.res_ret_ar_3_ma_2[2:], zero = False, lags = 40)
plt.title("ACF of residuals of returns", size = 24)
plt.show()

# %% [markdown]
# Its quiet surprising to see that we have more significant lags than AR and MA models (check the ACF plots above for the respective models). Therefore accounting for lags 5 periods ago could improve our predictions(Clearly the fifth variable is out of the blue area). So we should start with the ARMA(5,5) and go through the models regressively like ARMA(5,Q) or ARMA(P,5). Once we are prepared with all the models, we shall go ahead with the following steps.
#
# 1. Find all the models with all coefficients significant.
# 2. Run the LLR test for the nested ones (as done above).
# 3. Compare log-likelihood and AIC values for the others.
#
# ### Reevaluating Model Selection
